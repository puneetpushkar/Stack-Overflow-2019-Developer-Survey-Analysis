# %% [markdown]
# # DevReport Analysis
#
# Technology is changing on rapid scale, and stackoverflow is the most important part of the development workflow, and to understand the dev likings stack overflow does annual survey with the aim to know what's trending in the Software Developer Space.
#
# This Notebook consist of analysis on Stack Overflow dataset 2019, I have tried to formulate some question while looking at the dataset.
#
# This Notebook is made for anyone who is starting up in the field data analysis, and need some familiar dataset to which they can relate with,
# ***All the clearning and visualization is done in the process of solving the questions***
#
# If you feel like this notebook helps in anyway do **Upvote (^)** it, and if their is any suggestion do use the comment section
#
# Now lets start with the analysis

# %% [markdown]
# For this analysis we will use most commonly used Python library
# 1. **Numpy**: Numpy is used for mathematical computation with Python learn more at: {[Numpy docs](http://https://numpy.org/doc/stable/user/quickstart.html)}
# and
# 2. **Pandas**: Pandas is mainly used for Data Manipulation and Visualizaiton with Python, learn more at: {[Pandas docs](https://pandas.pydata.org/docs/user_guide/index.html)}

# %%
# Importing Libraries

import pandas as pd
import numpy as np

# %%
# loading dataset
df = pd.read_csv("../input/stack-overflow-developer-survey-results-2019/survey_results_public.csv")

# %%
df.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %% [markdown]
# The Most Important part of data analysis is:
# 1. Understanding the data {what data is all about}
# 2. Drawing Patterns while going through data columns
# 3. Formulate question {like what are the things that can be extracted from the dataset}
#
# Below are the some question that I have formulated:

# %% [markdown]
# ## What is the average age of developers when they wrote their first line of code?

# %%
#display the columns {Age1stCode}
df['Age1stCode']
# Out:
# 0         10
# 1         17
# 2         22
# 3         16
# 4         14
#         ...
# 88878    NaN
# 88879    NaN
# 88880    NaN
# 88881    NaN
# 88882     11
# Name: Age1stCode, Length: 88883, dtype: object

# %%
#check the datatype of the columns values
type(df['Age1stCode'][0])
# Out:
# str

# %%
#as we are supposed to find the average, so convert the values into the numeric format

df['Age1stCode'] = pd.to_numeric(df['Age1stCode'], errors = 'coerce')

# %%
type(df['Age1stCode'][0])
# Out:
# numpy.float64

# %%
avg_age = int(df['Age1stCode'].mean())

# %%
print ("The average age of developers when they write their first line of code is: ", avg_age)
# Out:
# The average age of developers when they write their first line of code is:  15

# %% [markdown]
# ## What is the percentage of developers who know python in each country?

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
#we have multiple values in the same cell, so we will split the values

new = df['LanguageWorkedWith'].str.split(";", expand = True)

# %%
new
# Out:
#                           0           1           2           3       4   \
# 0                   HTML/CSS        Java  JavaScript      Python    None
# 1                        C++    HTML/CSS      Python        None    None
# 2                   HTML/CSS        None        None        None    None
# 3                          C         C++          C#      Python     SQL
# 4                        C++    HTML/CSS        Java  JavaScript  Python
# ...                      ...         ...         ...         ...     ...
# 88878               HTML/CSS  JavaScript   Other(s):        None    None
# 88879                    NaN         NaN         NaN         NaN     NaN
# 88880                    NaN         NaN         NaN         NaN     NaN
# 88881                    NaN         NaN         NaN         NaN     NaN
# 88882  Bash/Shell/PowerShell    HTML/CSS        Java  JavaScript     PHP
#
#          5      6     7     8     9   ...    18    19    20    21    22    23  \
# 0      None   None  None  None  None  ...  None  None  None  None  None  None
# 1      None   None  None  None  None  ...  None  None  None  None  None  None
# 2      None   None  None  None  None  ...  None  None  None  None  None  None
# 3      None   None  None  None  None  ...  None  None  None  None  None  None
# 4       SQL    VBA  None  None  None  ...  None  None  None  None  None  None
# ...     ...    ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 88878  None   None  None  None  None  ...  None  None  None  None  None  None
# 88879   NaN    NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 88880   NaN    NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 88881   NaN    NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 88882   SQL  Swift  None  None  None  ...  None  None  None  None  None  None
#
#          24    25    26    27
# 0      None  None  None  None
# 1      None  None  None  None
# 2      None  None  None  None
# 3      None  None  None  None
# 4      None  None  None  None
# ...     ...   ...   ...   ...
# 88878  None  None  None  None
# 88879   NaN   NaN   NaN   NaN
# 88880   NaN   NaN   NaN   NaN
# 88881   NaN   NaN   NaN   NaN
# 88882  None  None  None  None
#
# [88883 rows x 28 columns]

# %%
#We are looking of people with python as a language by country

#transpose

new_t = new.T

# %%
new_t
# Out:
#          0         1         2       3           4     5           6      \
# 0     HTML/CSS       C++  HTML/CSS       C         C++  Java    HTML/CSS
# 1         Java  HTML/CSS      None     C++    HTML/CSS     R  JavaScript
# 2   JavaScript    Python      None      C#        Java   SQL        None
# 3       Python      None      None  Python  JavaScript  None        None
# 4         None      None      None     SQL      Python  None        None
# 5         None      None      None    None         SQL  None        None
# 6         None      None      None    None         VBA  None        None
# 7         None      None      None    None        None  None        None
# 8         None      None      None    None        None  None        None
# 9         None      None      None    None        None  None        None
# 10        None      None      None    None        None  None        None
# 11        None      None      None    None        None  None        None
# 12        None      None      None    None        None  None        None
# 13        None      None      None    None        None  None        None
# 14        None      None      None    None        None  None        None
# 15        None      None      None    None        None  None        None
# 16        None      None      None    None        None  None        None
# 17        None      None      None    None        None  None        None
# 18        None      None      None    None        None  None        None
# 19        None      None      None    None        None  None        None
# 20        None      None      None    None        None  None        None
# 21        None      None      None    None        None  None        None
# 22        None      None      None    None        None  None        None
# 23        None      None      None    None        None  None        None
# 24        None      None      None    None        None  None        None
# 25        None      None      None    None        None  None        None
# 26        None      None      None    None        None  None        None
# 27        None      None      None    None        None  None        None
#
#                     7                      8           9      ... 88873 88874  \
# 0   Bash/Shell/PowerShell  Bash/Shell/PowerShell          C#  ...   NaN   NaN
# 1                       C                     C#          Go  ...   NaN   NaN
# 2                     C++               HTML/CSS  JavaScript  ...   NaN   NaN
# 3                HTML/CSS             JavaScript      Python  ...   NaN   NaN
# 4                    Java                 Python           R  ...   NaN   NaN
# 5              JavaScript                   Ruby         SQL  ...   NaN   NaN
# 6                  Python                   Rust        None  ...   NaN   NaN
# 7                     SQL                    SQL        None  ...   NaN   NaN
# 8                    None             TypeScript        None  ...   NaN   NaN
# 9                    None            WebAssembly        None  ...   NaN   NaN
# 10                   None              Other(s):        None  ...   NaN   NaN
# 11                   None                   None        None  ...   NaN   NaN
# 12                   None                   None        None  ...   NaN   NaN
# 13                   None                   None        None  ...   NaN   NaN
# 14                   None                   None        None  ...   NaN   NaN
# 15                   None                   None        None  ...   NaN   NaN
# 16                   None                   None        None  ...   NaN   NaN
# 17                   None                   None        None  ...   NaN   NaN
# 18                   None                   None        None  ...   NaN   NaN
# 19                   None                   None        None  ...   NaN   NaN
# 20                   None                   None        None  ...   NaN   NaN
# 21                   None                   None        None  ...   NaN   NaN
# 22                   None                   None        None  ...   NaN   NaN
# 23                   None                   None        None  ...   NaN   NaN
# 24                   None                   None        None  ...   NaN   NaN
# 25                   None                   None        None  ...   NaN   NaN
# 26                   None                   None        None  ...   NaN   NaN
# 27                   None                   None        None  ...   NaN   NaN
#
#          88875       88876                  88877       88878 88879 88880  \
# 0     HTML/CSS    HTML/CSS  Bash/Shell/PowerShell    HTML/CSS   NaN   NaN
# 1         Java  JavaScript                     Go  JavaScript   NaN   NaN
# 2   JavaScript      Python               HTML/CSS   Other(s):   NaN   NaN
# 3         None        None             JavaScript        None   NaN   NaN
# 4         None        None            WebAssembly        None   NaN   NaN
# 5         None        None                   None        None   NaN   NaN
# 6         None        None                   None        None   NaN   NaN
# 7         None        None                   None        None   NaN   NaN
# 8         None        None                   None        None   NaN   NaN
# 9         None        None                   None        None   NaN   NaN
# 10        None        None                   None        None   NaN   NaN
# 11        None        None                   None        None   NaN   NaN
# 12        None        None                   None        None   NaN   NaN
# 13        None        None                   None        None   NaN   NaN
# 14        None        None                   None        None   NaN   NaN
# 15        None        None                   None        None   NaN   NaN
# 16        None        None                   None        None   NaN   NaN
# 17        None        None                   None        None   NaN   NaN
# 18        None        None                   None        None   NaN   NaN
# 19        None        None                   None        None   NaN   NaN
# 20        None        None                   None        None   NaN   NaN
# 21        None        None                   None        None   NaN   NaN
# 22        None        None                   None        None   NaN   NaN
# 23        None        None                   None        None   NaN   NaN
# 24        None        None                   None        None   NaN   NaN
# 25        None        None                   None        None   NaN   NaN
# 26        None        None                   None        None   NaN   NaN
# 27        None        None                   None        None   NaN   NaN
#
#    88881                  88882
# 0    NaN  Bash/Shell/PowerShell
# 1    NaN               HTML/CSS
# 2    NaN                   Java
# 3    NaN             JavaScript
# 4    NaN                    PHP
# 5    NaN                    SQL
# 6    NaN                  Swift
# 7    NaN                   None
# 8    NaN                   None
# 9    NaN                   None
# 10   NaN                   None
# 11   NaN                   None
# 12   NaN                   None
# 13   NaN                   None
# 14   NaN                   None
# 15   NaN                   None
# 16   NaN                   None
# 17   NaN                   None
# 18   NaN                   None
# 19   NaN                   None
# 20   NaN                   None
# 21   NaN                   None
# 22   NaN                   None
# 23   NaN                   None
# 24   NaN                   None
# 25   NaN                   None
# 26   NaN                   None
# 27   NaN                   None
#
# [28 rows x 88883 columns]

# %%
count = new.shape[0]

# %%
#adding a new columns with name 'if_python' and will apply the value 0 with it
df['is_python'] = 0

# %%
df['is_python']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 88878    0
# 88879    0
# 88880    0
# 88881    0
# 88882    0
# Name: is_python, Length: 88883, dtype: int64

# %%
for i in range(0,count):
    if 'Python' in new_t[i].unique():
        df.at[i, 'is_python'] = 1

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
# 6                       Never
# 7     Less than once per year
# 8  Once a month or more often
# 9  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
# 6  The quality of OSS and closed source software ...
# 7  OSS is, on average, of HIGHER quality than pro...
# 8  The quality of OSS and closed source software ...
# 9  OSS is, on average, of HIGHER quality than pro...
#
#                                           Employment                 Country  \
# 0             Not employed, and not looking for work          United Kingdom
# 1                 Not employed, but looking for work  Bosnia and Herzegovina
# 2                                 Employed full-time                Thailand
# 3                                 Employed full-time           United States
# 4                                 Employed full-time                 Ukraine
# 5                                 Employed full-time                  Canada
# 6  Independent contractor, freelancer, or self-em...                 Ukraine
# 7                 Not employed, but looking for work                   India
# 8                                 Employed full-time             New Zealand
# 9                                 Employed full-time                   India
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7             NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8              No  Some college/university study without earning ...
# 9              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
# 5                          Mathematics or statistics  ...
# 6  Another engineering discipline (ex. civil, ele...  ...
# 7  Computer science, computer engineering, or sof...  ...
# 8  Computer science, computer engineering, or sof...  ...
# 9                                                NaN  ...
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
# 5  Tech articles written by other developers;Indu...  28.0    Man    No
# 6                                                NaN  42.0    Man    No
# 7  Tech articles written by other developers;Indu...  24.0    Man    No
# 8                                                NaN  23.0    Man    No
# 9  Tech articles written by other developers;Tech...   NaN    NaN   NaN
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
# 5  Straight / Heterosexual                                East Asian
# 6  Straight / Heterosexual              White or of European descent
# 7  Straight / Heterosexual                                       NaN
# 8                 Bisexual              White or of European descent
# 9                      NaN                                       NaN
#
#   Dependents           SurveyLength                  SurveyEase is_python
# 0         No  Appropriate in length  Neither easy nor difficult         1
# 1         No  Appropriate in length  Neither easy nor difficult         1
# 2        Yes  Appropriate in length  Neither easy nor difficult         0
# 3         No  Appropriate in length                        Easy         1
# 4         No  Appropriate in length                        Easy         1
# 5         No               Too long  Neither easy nor difficult         0
# 6        Yes  Appropriate in length  Neither easy nor difficult         0
# 7        NaN  Appropriate in length  Neither easy nor difficult         1
# 8         No  Appropriate in length  Neither easy nor difficult         1
# 9        Yes               Too long                   Difficult         1
#
# [10 rows x 86 columns]

# %%
#finding the mean of the people with country

df.groupby('Country').mean()
# Out:
#                                         Respondent  Age1stCode     CompTotal  \
# Country
# Afghanistan                           47441.431818   18.818182  5.418654e+07
# Albania                               41695.546512   16.783133  1.707424e+05
# Algeria                               43010.126866   17.728682  7.544398e+04
# Andorra                               50079.857143   10.666667  7.650000e+04
# Angola                                50569.400000   18.250000  2.020000e+05
# ...                                            ...         ...           ...
# Venezuela, Bolivarian Republic of...  43461.170455   16.397727  1.174443e+05
# Viet Nam                              43895.337662   15.613636  2.613438e+07
# Yemen                                 45331.157895   20.176471  1.375000e+05
# Zambia                                42096.833333   21.500000  2.774375e+04
# Zimbabwe                              37455.410256   19.421053  7.841667e+03
#
#                                       ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Country
# Afghanistan                           101953.333333    55.352941   14.062500
# Albania                                21833.700000    40.121212    5.781818
# Algeria                                34924.047619    38.220930    6.413793
# Andorra                               160931.000000    42.000000    2.500000
# Angola                                  7764.000000    45.000000   10.000000
# ...                                             ...          ...         ...
# Venezuela, Bolivarian Republic of...   14581.627907    40.444444    6.717949
# Viet Nam                               17233.436782    44.602679    8.407767
# Yemen                                  16909.166667    41.250000   12.800000
# Zambia                                 10075.375000    48.125000   18.400000
# Zimbabwe                               34046.666667    43.666667   10.636364
#
#                                             Age  is_python
# Country
# Afghanistan                           27.913043   0.181818
# Albania                               25.145833   0.267442
# Algeria                               27.284404   0.298507
# Andorra                               28.000000   0.000000
# Angola                                26.666667   0.400000
# ...                                         ...        ...
# Venezuela, Bolivarian Republic of...  28.301205   0.318182
# Viet Nam                              26.739884   0.337662
# Yemen                                 28.117647   0.157895
# Zambia                                28.000000   0.333333
# Zimbabwe                              27.371429   0.358974
#
# [179 rows x 8 columns]

# %%
#basic math to find the percentage 😛
(df.groupby('Country')['is_python'].mean())*100
# Out:
# Country
# Afghanistan                             18.181818
# Albania                                 26.744186
# Algeria                                 29.850746
# Andorra                                  0.000000
# Angola                                  40.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    31.818182
# Viet Nam                                33.766234
# Yemen                                   15.789474
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: is_python, Length: 179, dtype: float64

# %% [markdown]
# ### Adding Continents to the table
#
# we have table with the country in it, but what if we want to add the continents in it
# we will use python package **"pycountry_convert as pc"**

# %%
df['Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %% [markdown]
# Cleaning the country columns, because many country in columns have abrevated values

# %%
index_names = df[df['Country']=='Timor-Leste'].index
df.drop(index_names, inplace=True)

# %%
df['Country'] = df['Country'].replace(['Hong Kong (S.A.R.)'],'Hong Kong')
df['Country'] = df['Country'].replace(['Libyan Arab Jamahiriya'],'Libya')
df['Country'] = df['Country'].replace(['Venezuela, Bolivarian Republic of...'],'Venezuela')
df['Country'] = df['Country'].replace(['The former Yugoslav Republic of Macedonia'],'North Macedonia')
df['Country'] = df['Country'].replace(['Republic of Korea'],'South Korea')
df['Country'] = df['Country'].replace(['Congo, Republic of the...'],'Congo')

# %%
pip install pycountry_convert as pc
# Out:
# Collecting pycountry_convert
#   Downloading pycountry_convert-0.7.2-py3-none-any.whl (13 kB)
# Collecting as
#   Downloading as-0.1-py3-none-any.whl (2.2 kB)
# Collecting pc
#   Downloading pc-0.0.3.tar.gz (5.7 kB)
# Requirement already satisfied: pycountry>=16.11.27.1 in /opt/conda/lib/python3.7/site-packages (from pycountry_convert) (20.7.3)
# Collecting pprintpp>=0.3.0
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: wheel>=0.30.0 in /opt/conda/lib/python3.7/site-packages (from pycountry_convert) (0.34.2)
# Requirement already satisfied: pytest-mock>=1.6.3 in /opt/conda/lib/python3.7/site-packages (from pycountry_convert) (3.3.1)
# Requirement already satisfied: pytest>=3.4.0 in /opt/conda/lib/python3.7/site-packages (from pycountry_convert) (5.4.1)
# Collecting repoze.lru>=0.7
#   Downloading repoze.lru-0.7-py3-none-any.whl (10 kB)
# Requirement already satisfied: pytest-cov>=2.5.1 in /opt/conda/lib/python3.7/site-packages (from pycountry_convert) (2.10.1)
# Requirement already satisfied: py>=1.5.0 in /opt/conda/lib/python3.7/site-packages (from pytest>=3.4.0->pycountry_convert) (1.8.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from pytest>=3.4.0->pycountry_convert) (20.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from pytest>=3.4.0->pycountry_convert) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /opt/conda/lib/python3.7/site-packages (from pytest>=3.4.0->pycountry_convert) (8.2.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest>=3.4.0->pycountry_convert) (0.13.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from pytest>=3.4.0->pycountry_convert) (0.1.9)
# Requirement already satisfied: importlib-metadata>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest>=3.4.0->pycountry_convert) (2.0.0)
# Requirement already satisfied: coverage>=4.4 in /opt/conda/lib/python3.7/site-packages (from pytest-cov>=2.5.1->pycountry_convert) (5.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->pytest>=3.4.0->pycountry_convert) (2.4.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from packaging->pytest>=3.4.0->pycountry_convert) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest>=3.4.0->pycountry_convert) (3.1.0)
# Building wheels for collected packages: pc
# done
#   Created wheel for pc: filename=pc-0.0.3-py3-none-any.whl size=6175 sha256=ef0873ad23978f6818947e276f667002cf907fade0150ed0bf265cdd49cc0a7a
#   Stored in directory: /root/.cache/pip/wheels/d9/44/dd/d6ea155fcf51b584d1ed91bedc60ecaf5745e3b699e65b5b45
# Successfully built pc
# Installing collected packages: pprintpp, repoze.lru, pycountry-convert, as, pc
# Successfully installed as-0.1 pc-0.0.3 pprintpp-0.4.0 pycountry-convert-0.7.2 repoze.lru-0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
#for adding continents field as according with country

import pycountry_convert as pc

def country_to_continent(country_name):

    country_alpha2 = pc.country_name_to_country_alpha2(country_name)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    return country_continent_name

# Example
row_count = 0
for i in df['Country']:
  i = str(i)
  if i == 'Other Country (Not Listed Above)' or i == 'nan':
    df.at[row_count,'Continent'] = 'NA'
    continue

  cont = country_to_continent(i)
  df.at[row_count,'Continent'] = cont 
  row_count += 1

# %% [markdown]
# ## What is the average salary of developer based on Continents?

# %%
#ConvertedComp: Compansasion of the salary as provided in the dataset
df['ConvertedComp']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# 12853        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
#😛
df['ConvertedComp'].mean()
# Out:
# 127108.90421339257

# %%
#grouping the compensation according to the continent 
(df.groupby('Continent')['ConvertedComp'].mean())
# Out:
# Continent
# Africa           125978.401639
# Asia             125371.035023
# Europe           125454.243098
# North America    130332.328250
# Oceania          133850.459442
# South America    125968.272809
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# ## Which will be the most desired programming language for the year 2020?

# %%
df['LanguageDesireNextYear']
# Out:
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
#                               ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
# 12853                                                NaN
# Name: LanguageDesireNextYear, Length: 88883, dtype: object

# %%
#spling the values with their values:

lang_count = {}
for i in df['LanguageDesireNextYear']:
  i  = str(i)
  j = i.split(';')
  for a in j:
    if a in lang_count:
      lang_count[a]+=1
    else:
       lang_count[a] = 1

# %%
print(lang_count)
# Out:
# {'C': 11142, 'C++': 16856, 'C#': 22449, 'Go': 17059, 'HTML/CSS': 36644, 'Java': 23508, 'JavaScript': 44738, 'Python': 40005, 'SQL': 33565, 'Elixir': 3787, 'WebAssembly': 8439, 'Scala': 5561, 'Bash/Shell/PowerShell': 21302, 'Erlang': 2124, 'Ruby': 7251, 'Rust': 10497, 'TypeScript': 23719, 'Other(s):': 7912, 'Kotlin': 13260, 'R': 6733, 'Assembly': 4659, 'Objective-C': 2851, 'PHP': 12837, 'Swift': 8799, 'VBA': 1641, 'Clojure': 2752, 'Dart': 4428, 'nan': 4796, 'F#': 3521}

# %%
type (lang_count)
# Out:
# dict

# %%
# max of a dictionary
lang_count1 = max(lang_count, key = lang_count.get)
print("The most desired languaage for 2020 is: ", lang_count1)
# Out:
# The most desired languaage for 2020 is:  JavaScript

# %% [markdown]
# ## What is the distribution of people who code as a hobby based on gender and continent? **

# %%
#categorizing {Men, Women, Other}

Gender = []
for i in df['Gender']:
    if (i=='Man') or (i== 'Man;Non-binary, genderqueer, or gender non-conforming'):
        Gender.append('Man')
    elif (i=='Woman') or (i=='Woman;Non-binary, genderqueer, or gender non-conforming') or (i=='Woman;Man;Non-binary, genderqueer, or gender non-conforming'):
        Gender.append('Woman')
    else:
        Gender.append('Others')
df['Gender'] = Gender
df['Gender'] = df['Gender'].astype('category')

# %%
df['Gender'].value_counts()
# Out:
# Man       78100
# Woman      6576
# Others     4207
# Name: Gender, dtype: int64

# %%
Hobbyist = []
for i in df['Hobbyist']:
  if i == 'Yes':
    Hobbyist.append(1)
  else:
    Hobbyist.append(0)
df['Hobbyist'] = Hobbyist

# %%
df['Hobbyist']
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 88879    0
# 88880    0
# 88881    0
# 88882    1
# 12853    0
# Name: Hobbyist, Length: 88883, dtype: int64

# %%
df.groupby(['Continent', 'Gender'])['Hobbyist'].count()
# Out:
# Continent      Gender
# Africa         Man        2420
#                Others      148
#                Woman       181
# Asia           Man       16309
#                Others      905
#                Woman      1358
# Europe         Man       31568
#                Others     1679
#                Woman      2596
# North America  Man       22445
#                Others     1098
#                Woman      1951
# Oceania        Man        2135
#                Others      123
#                Woman       176
# South America  Man        3094
#                Others      150
#                Woman       278
# Name: Hobbyist, dtype: int64

# %% [markdown]
# ## What is job and career satisfaction of developer based on their gender and continent?

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase',
#        'is_python', 'Continent'],
#       dtype='object')

# %%
job = df. groupby(['Continent', 'Gender', 'JobSat'])['Respondent'].count().reset_index()

# %%
job = job.rename(columns= {'Respondent':'Count'})

# %%
job
# Out:
#         Continent Gender                              JobSat  Count
# 0          Africa    Man  Neither satisfied nor dissatisfied    223
# 1          Africa    Man               Slightly dissatisfied    323
# 2          Africa    Man                  Slightly satisfied    667
# 3          Africa    Man                   Very dissatisfied    141
# 4          Africa    Man                      Very satisfied    599
# ..            ...    ...                                 ...    ...
# 85  South America  Woman  Neither satisfied nor dissatisfied     26
# 86  South America  Woman               Slightly dissatisfied     37
# 87  South America  Woman                  Slightly satisfied     60
# 88  South America  Woman                   Very dissatisfied     11
# 89  South America  Woman                      Very satisfied     81
#
# [90 rows x 4 columns]
